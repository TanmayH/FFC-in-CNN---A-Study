# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch
from google.colab import drive
drive.mount('/content/drive')
from glob import glob
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torchsummary import summary
from fastai.metrics import accuracy
from fastai.vision import *
import numpy as np
# !pip install fft-conv-pytorch
from fft_conv_pytorch import fft_conv, FFTConv2d
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: fft-conv-pytorch in /usr/local/lib/python3.7/dist-packages (1.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fft-conv-pytorch) (1.21.5)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.7/dist-packages (from fft-conv-pytorch) (1.10.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.8->fft-conv-pytorch) (3.10.0.2)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from fastai.vision.data import normalize
path = "/content/drive/MyDrive/Dataset/brain_tumor_dataset_grayscale"
np.random.seed(41)
defaults = SimpleNamespace(cmap='L', return_fig=False, silent=False)
data = ImageDataBunch.from_folder(path, train="Train", valid ="Valid", valid_pct=0.2,ds_tfms=get_transforms(), size=(224,224), bs=16, num_workers=4)
for itemList in ["train_dl", "valid_dl", "fix_dl", "test_dl"]:
    itemList = getattr(data, itemList)
    if itemList: itemList.x.convert_mode = "L"

# %%
print (data.one_batch()[0].shape)
print (data.classes, data.c, len(data.train_ds), len(data.valid_ds))
print (data.train_ds.classes)
print (data.valid_ds.classes)
# Out:
# torch.Size([16, 1, 224, 224])
# ['no', 'yes'] 2 203 50
# ['no', 'yes']
# ['no', 'yes']

# %% [markdown]
# With FFT Conv Layers

# %%
def fft_conv_block(ni, nf, size=3, stride=1):
    for_pad = lambda s: s if s > 2 else 3
    return nn.Sequential(
        FFTConv2d(ni, nf, kernel_size=size, stride=stride,
                  padding=(for_pad(size) - 1)//2, bias=False), 
        nn.BatchNorm2d(nf),
        nn.LeakyReLU(negative_slope=0.1, inplace=True)  
    )

def conv_block(ni, nf, size=3, stride=1):
    for_pad = lambda s: s if s > 2 else 3
    return nn.Sequential(
        nn.Conv2d(ni, nf, kernel_size=size, stride=stride,
                  padding=(for_pad(size) - 1)//2, bias=False), 
        nn.BatchNorm2d(nf),
        nn.LeakyReLU(negative_slope=0.1, inplace=True)  
    )

def triple_conv(ni, nf):
    return nn.Sequential(
        conv_block(ni, nf),
        conv_block(nf, ni, size=1),  
        conv_block(ni, nf)
    )
def fft_triple_conv(ni, nf,size):
    return nn.Sequential(
        fft_conv_block(ni, nf,size),
        conv_block(nf, ni, size=1),  
        fft_conv_block(ni, nf, size)
    )
def maxpooling():
    return nn.MaxPool2d(2, stride=2)

# %%
fft_model2 = nn.Sequential(
    fft_conv_block(1, 8, 17),
    maxpooling(),
    fft_conv_block(8, 16, 17),
    maxpooling(),
    triple_conv(16,32),
    maxpooling(),
    triple_conv(32, 64),
    maxpooling(),
    triple_conv(64, 128),
    maxpooling(),
    triple_conv(128, 256),
    conv_block(256, 128, size=1),
    conv_block(128, 256),
    conv_block(256,2),
    nn.Flatten(),
    nn.Linear(288, 2)
)

# %%
fft_learn2 = Learner(data, fft_model2, loss_func = nn.CrossEntropyLoss(), metrics=accuracy)
print(fft_learn2.summary())
# Out:
# Sequential
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# _FFTConv             [8, 224, 224]        2,312      True
# ______________________________________________________________________
# BatchNorm2d          [8, 224, 224]        16         True
# ______________________________________________________________________
# LeakyReLU            [8, 224, 224]        0          False
# ______________________________________________________________________
# MaxPool2d            [8, 112, 112]        0          False
# ______________________________________________________________________
# _FFTConv             [16, 112, 112]       36,992     True
# ______________________________________________________________________
# BatchNorm2d          [16, 112, 112]       32         True
# ______________________________________________________________________
# LeakyReLU            [16, 112, 112]       0          False
# ______________________________________________________________________
# MaxPool2d            [16, 56, 56]         0          False
# ______________________________________________________________________
# Conv2d               [32, 56, 56]         4,608      True
# ______________________________________________________________________
# BatchNorm2d          [32, 56, 56]         64         True
# ______________________________________________________________________
# LeakyReLU            [32, 56, 56]         0          False
# ______________________________________________________________________
# Conv2d               [16, 58, 58]         512        True
# ______________________________________________________________________
# BatchNorm2d          [16, 58, 58]         32         True
# ______________________________________________________________________
# LeakyReLU            [16, 58, 58]         0          False
# ______________________________________________________________________
# Conv2d               [32, 58, 58]         4,608      True
# ______________________________________________________________________
# BatchNorm2d          [32, 58, 58]         64         True
# ______________________________________________________________________
# LeakyReLU            [32, 58, 58]         0          False
# ______________________________________________________________________
# MaxPool2d            [32, 29, 29]         0          False
# ______________________________________________________________________
# Conv2d               [64, 29, 29]         18,432     True
# ______________________________________________________________________
# BatchNorm2d          [64, 29, 29]         128        True
# ______________________________________________________________________
# LeakyReLU            [64, 29, 29]         0          False
# ______________________________________________________________________
# Conv2d               [32, 31, 31]         2,048      True
# ______________________________________________________________________
# BatchNorm2d          [32, 31, 31]         64         True
# ______________________________________________________________________
# LeakyReLU            [32, 31, 31]         0          False
# ______________________________________________________________________
# Conv2d               [64, 31, 31]         18,432     True
# ______________________________________________________________________
# BatchNorm2d          [64, 31, 31]         128        True
# ______________________________________________________________________
# LeakyReLU            [64, 31, 31]         0          False
# ______________________________________________________________________
# MaxPool2d            [64, 15, 15]         0          False
# ______________________________________________________________________
# Conv2d               [128, 15, 15]        73,728     True
# ______________________________________________________________________
# BatchNorm2d          [128, 15, 15]        256        True
# ______________________________________________________________________
# LeakyReLU            [128, 15, 15]        0          False
# ______________________________________________________________________
# Conv2d               [64, 17, 17]         8,192      True
# ______________________________________________________________________
# BatchNorm2d          [64, 17, 17]         128        True
# ______________________________________________________________________
# LeakyReLU            [64, 17, 17]         0          False
# ______________________________________________________________________
# Conv2d               [128, 17, 17]        73,728     True
# ______________________________________________________________________
# BatchNorm2d          [128, 17, 17]        256        True
# ______________________________________________________________________
# LeakyReLU            [128, 17, 17]        0          False
# ______________________________________________________________________
# MaxPool2d            [128, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [256, 8, 8]          294,912    True
# ______________________________________________________________________
# BatchNorm2d          [256, 8, 8]          512        True
# ______________________________________________________________________
# LeakyReLU            [256, 8, 8]          0          False
# ______________________________________________________________________
# Conv2d               [128, 10, 10]        32,768     True
# ______________________________________________________________________
# BatchNorm2d          [128, 10, 10]        256        True
# ______________________________________________________________________
# LeakyReLU            [128, 10, 10]        0          False
# ______________________________________________________________________
# Conv2d               [256, 10, 10]        294,912    True
# ______________________________________________________________________
# BatchNorm2d          [256, 10, 10]        512        True
# ______________________________________________________________________
# LeakyReLU            [256, 10, 10]        0          False
# ______________________________________________________________________
# Conv2d               [128, 12, 12]        32,768     True
# ______________________________________________________________________
# BatchNorm2d          [128, 12, 12]        256        True
# ______________________________________________________________________
# LeakyReLU            [128, 12, 12]        0          False
# ______________________________________________________________________
# Conv2d               [256, 12, 12]        294,912    True
# ______________________________________________________________________
# BatchNorm2d          [256, 12, 12]        512        True
# ______________________________________________________________________
# LeakyReLU            [256, 12, 12]        0          False
# ______________________________________________________________________
# Conv2d               [2, 12, 12]          4,608      True
# ______________________________________________________________________
# BatchNorm2d          [2, 12, 12]          4          True
# ______________________________________________________________________
# LeakyReLU            [2, 12, 12]          0          False
# ______________________________________________________________________
# Flatten              [288]                0          False
# ______________________________________________________________________
# Linear               [2]                  578        True
# ______________________________________________________________________
#
# Total params: 1,202,270
# Total trainable params: 1,202,270
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : CrossEntropyLoss
# ======================================================================
# Callbacks functions applied

# %%
fft_learn2.fit_one_cycle(100, max_lr=5e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.654183</td>
#       <td>0.768266</td>
#       <td>0.380000</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.586712</td>
#       <td>0.720997</td>
#       <td>0.380000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.552440</td>
#       <td>0.538237</td>
#       <td>0.720000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.544288</td>
#       <td>0.435358</td>
#       <td>0.800000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.532291</td>
#       <td>0.539486</td>
#       <td>0.740000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.515355</td>
#       <td>0.443899</td>
#       <td>0.740000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.507209</td>
#       <td>0.477413</td>
#       <td>0.800000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.493019</td>
#       <td>0.395542</td>
#       <td>0.840000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.493207</td>
#       <td>0.449204</td>
#       <td>0.840000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.503839</td>
#       <td>0.421725</td>
#       <td>0.800000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.497880</td>
#       <td>1.154678</td>
#       <td>0.620000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.499027</td>
#       <td>1.039207</td>
#       <td>0.680000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.498235</td>
#       <td>0.453598</td>
#       <td>0.800000</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.485199</td>
#       <td>0.589216</td>
#       <td>0.780000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.496418</td>
#       <td>0.449464</td>
#       <td>0.780000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0